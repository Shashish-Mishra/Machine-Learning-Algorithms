# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['shashish','suneel','karishma','abhishek'],
    "marks":[50,84,79,52],
    "city":['lucknow','kolkata','mumbai','pune']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#        name  marks     city
# 0  shashish     50  lucknow
# 1    suneel     84  kolkata
# 2  karishma     79   mumbai
# 3  abhishek     52     pune

# %%
df.to_csv('home.csv')#with index

# %%
df.to_csv('home1.csv',index=False)#winthout index

# %%
df.head()
# Out:
#        name  marks     city
# 0  shashish     50  lucknow
# 1    suneel     84  kolkata
# 2  karishma     79   mumbai
# 3  abhishek     52     pune

# %%
df=pd.read_csv('http://bit.ly/imdbratings')

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df.head(15)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
df.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %%
df.tail(20)
# Out:
#      star_rating                                            title  \
# 959          7.4                             Deconstructing Harry
# 960          7.4                                 The Way Way Back
# 961          7.4                                           Capote
# 962          7.4                               Driving Miss Daisy
# 963          7.4                                  La Femme Nikita
# 964          7.4                                          Lincoln
# 965          7.4                                        Limitless
# 966          7.4                               The Simpsons Movie
# 967          7.4                                         The Rock
# 968          7.4                              The English Patient
# 969          7.4                              Law Abiding Citizen
# 970          7.4                                      Wonder Boys
# 971          7.4                               Death at a Funeral
# ...

# %%
df=pd.DataFrame(dict1)

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   66.250000
# std    17.745892
# min    50.000000
# 25%    51.500000
# 50%    65.500000
# 75%    80.250000
# max    84.000000

# %%
df['name']
# Out:
# 0    shashish
# 1      suneel
# 2    karishma
# 3    abhishek
# Name: name, dtype: object

# %%
df
# Out:
#        name  marks     city
# 0  shashish     50  lucknow
# 1    suneel     84  kolkata
# 2  karishma     79   mumbai
# 3  abhishek     52     pune

# %%
df['city']
# Out:
# 0    lucknow
# 1    kolkata
# 2     mumbai
# 3       pune
# Name: city, dtype: object

# %%
df['city'][3]='lucknow'
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#        name  marks     city
# 0  shashish     50  lucknow
# 1    suneel     84  kolkata
# 2  karishma     79   mumbai
# 3  abhishek     52  lucknow

# %%
df
# Out:
#        name  marks     city
# 0  shashish     50  lucknow
# 1    suneel     84  kolkata
# 2  karishma     79   mumbai
# 3  abhishek     52  lucknow

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#        name  marks     city
# 0  shashish     50  lucknow
# 1    suneel     84  kolkata
# 2  karishma     79   mumbai
# 3  abhishek     52     pune

# %%
df1=pd.read_csv('home.csv')

# %%
df1
# Out:
#    Unnamed: 0      name  marks     city
# 0           0  shashish     50  lucknow
# 1           1    suneel     84  kolkata
# 2           2  karishma     79   mumbai
# 3           3  abhishek     52     pune

# %%
df.drop(0,axis=0)
# Out:
#        name  marks     city
# 1    suneel     84  kolkata
# 2  karishma     79   mumbai
# 3  abhishek     52     pune

# %%
df
# Out:
#        name  marks     city
# 0  shashish     50  lucknow
# 1    suneel     84  kolkata
# 2  karishma     79   mumbai
# 3  abhishek     52     pune

# %%
df.index=['a','b','c','d']

# %%
df
# Out:
#        name  marks     city
# a  shashish     50  lucknow
# b    suneel     84  kolkata
# c  karishma     79   mumbai
# d  abhishek     52     pune

# %% [markdown]
# Pandas is opensource library
#
# it uses power and speed of numpy for data analysis and preprocessing
#
# it provides rich and highly robust data.
#
# **data structures **
#
# a) Series:- 1d array with index that stores cpolumn or row in a dataframe(same type of data)
# b) Dataframe:- tabular spreadsheet with multiple rows and columns having different kind of data

# %%
ser=pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.521142
# 1     0.956304
# 2     0.849277
# 3     0.108347
# 4     0.237782
# 5     0.596729
# 6     0.858732
# 7     0.458149
# 8     0.707908
# 9     0.470626
# 10    0.745624
# 11    0.907104
# 12    0.886806
# 13    0.544322
# 14    0.241444
# 15    0.161936
# 16    0.628085
# 17    0.788055
# 18    0.110887
# 19    0.631826
# 20    0.151510
# 21    0.458747
# 22    0.291234
# 23    0.290022
# 24    0.313092
# 25    0.144244
# 26    0.324819
# 27    0.030122
# 28    0.647071
# 29    0.153080
# 30    0.351447
# 31    0.549248
# 32    0.373693
# 33    0.536976
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.126055  0.267806  0.113698  0.749311  0.156837
# 1    0.970310  0.732403  0.799913  0.234502  0.496028
# 2    0.116199  0.883039  0.853792  0.127088  0.866747
# 3    0.945940  0.202907  0.052465  0.024824  0.991840
# 4    0.871781  0.638268  0.508543  0.541303  0.809209
# ..        ...       ...       ...       ...       ...
# 329  0.410729  0.894751  0.048551  0.944437  0.626941
# 330  0.172131  0.694113  0.267358  0.716173  0.760633
# 331  0.517158  0.065819  0.290983  0.233206  0.508646
# 332  0.632736  0.227357  0.286759  0.713304  0.683728
# 333  0.212510  0.644979  0.762698  0.851618  0.010555
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
.088621  0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf2
# Out:
#              0         1         2         3         4
# 0    52.250000  0.994032  0.800005  0.650373  0.266525
# 1     0.581182  0.113125  0.166101  0.647029  0.520808
# 2     0.560521  0.628288  0.577837  0.911383  0.627974
# 3     0.690152  0.543856  0.791858  0.412409  0.569077
# 4     0.695516  0.793135  0.423228  0.548832  0.763728
# ..         ...       ...       ...       ...       ...
# 329   0.988176  0.369332  0.283541  0.260270  0.627546
# 330   0.007881  0.385615  0.354426  0.618249  0.341204
# 331   0.119927  0.124247  0.895262  0.056623  0.178330
# 332   0.595859  0.187111  0.502048  0.132103  0.883491
# 333   0.088621  0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
id(newdf)
# Out:
# 1269794859592

# %%
id(newdf2)
# Out:
# 1269794893960

# %%
newdf.loc[0,0]=654

# %%
newdf
# Out:
#               0         1         2         3         4
# 0    654.000000  0.994032  0.800005  0.650373  0.266525
# 1      0.581182  0.113125  0.166101  0.647029  0.520808
# 2      0.560521  0.628288  0.577837  0.911383  0.627974
# 3      0.690152  0.543856  0.791858  0.412409  0.569077
# 4      0.695516  0.793135  0.423228  0.548832  0.763728
# ..          ...       ...       ...       ...       ...
# 329    0.988176  0.369332  0.283541  0.260270  0.627546
# 330    0.007881  0.385615  0.354426  0.618249  0.341204
# 331    0.119927  0.124247  0.895262  0.056623  0.178330
# 332    0.595859  0.187111  0.502048  0.132103  0.883491
# 333    0.088621  0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf.columns=list('ABCDE')

# %%
newdf
# Out:
#               A         B         C         D         E
# 0    654.000000  0.994032  0.800005  0.650373  0.266525
# 1      0.581182  0.113125  0.166101  0.647029  0.520808
# 2      0.560521  0.628288  0.577837  0.911383  0.627974
# 3      0.690152  0.543856  0.791858  0.412409  0.569077
# 4      0.695516  0.793135  0.423228  0.548832  0.763728
# ..          ...       ...       ...       ...       ...
# 329    0.988176  0.369332  0.283541  0.260270  0.627546
# 330    0.007881  0.385615  0.354426  0.618249  0.341204
# 331    0.119927  0.124247  0.895262  0.056623  0.178330
# 332    0.595859  0.187111  0.502048  0.132103  0.883491
# 333    0.088621  0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,'B']=999

# %%
newdf
# Out:
#               A           B         C         D         E
# 0    654.000000  999.000000  0.800005  0.650373  0.266525
# 1      0.581182    0.113125  0.166101  0.647029  0.520808
# 2      0.560521    0.628288  0.577837  0.911383  0.627974
# 3      0.690152    0.543856  0.791858  0.412409  0.569077
# 4      0.695516    0.793135  0.423228  0.548832  0.763728
# ..          ...         ...       ...       ...       ...
# 329    0.988176    0.369332  0.283541  0.260270  0.627546
# 330    0.007881    0.385615  0.354426  0.618249  0.341204
# 331    0.119927    0.124247  0.895262  0.056623  0.178330
# 332    0.595859    0.187111  0.502048  0.132103  0.883491
# 333    0.088621    0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,1]=888

# %%
newdf
# Out:
#               A           B         C         D         E      1
# 0    654.000000  999.000000  0.800005  0.650373  0.266525  888.0
# 1      0.581182    0.113125  0.166101  0.647029  0.520808    NaN
# 2      0.560521    0.628288  0.577837  0.911383  0.627974    NaN
# 3      0.690152    0.543856  0.791858  0.412409  0.569077    NaN
# 4      0.695516    0.793135  0.423228  0.548832  0.763728    NaN
# ..          ...         ...       ...       ...       ...    ...
# 329    0.988176    0.369332  0.283541  0.260270  0.627546    NaN
# 330    0.007881    0.385615  0.354426  0.618249  0.341204    NaN
# 331    0.119927    0.124247  0.895262  0.056623  0.178330    NaN
# 332    0.595859    0.187111  0.502048  0.132103  0.883491    NaN
# 333    0.088621    0.832595  0.471849  0.398521  0.738020    NaN
#
# [334 rows x 6 columns]

# %%
newdf.drop(1,axis=1)
# Out:
#               A           B         C         D         E
# 0    654.000000  999.000000  0.800005  0.650373  0.266525
# 1      0.581182    0.113125  0.166101  0.647029  0.520808
# 2      0.560521    0.628288  0.577837  0.911383  0.627974
# 3      0.690152    0.543856  0.791858  0.412409  0.569077
# 4      0.695516    0.793135  0.423228  0.548832  0.763728
# ..          ...         ...       ...       ...       ...
# 329    0.988176    0.369332  0.283541  0.260270  0.627546
# 330    0.007881    0.385615  0.354426  0.618249  0.341204
# 331    0.119927    0.124247  0.895262  0.056623  0.178330
# 332    0.595859    0.187111  0.502048  0.132103  0.883491
# 333    0.088621    0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf.loc[[0,1,2,3],['A',"B"]]
# Out:
#             A           B
# 0  654.000000  999.000000
# 1    0.581182    0.113125
# 2    0.560521    0.628288
# 3    0.690152    0.543856

# %%
newdf.loc[:4,['C',"D",'E']]
# Out:
#           C         D         E
# 0  0.800005  0.650373  0.266525
# 1  0.166101  0.647029  0.520808
# 2  0.577837  0.911383  0.627974
# 3  0.791858  0.412409  0.569077
# 4  0.423228  0.548832  0.763728

# %%
newdf.loc[0:3,:]
# Out:
#             A           B         C         D         E      1
# 0  654.000000  999.000000  0.800005  0.650373  0.266525  888.0
# 1    0.581182    0.113125  0.166101  0.647029  0.520808    NaN
# 2    0.560521    0.628288  0.577837  0.911383  0.627974    NaN
# 3    0.690152    0.543856  0.791858  0.412409  0.569077    NaN

# %%
newdf
# Out:
#               A           B         C         D         E      1
# 0    654.000000  999.000000  0.800005  0.650373  0.266525  888.0
# 1      0.581182    0.113125  0.166101  0.647029  0.520808    NaN
# 2      0.560521    0.628288  0.577837  0.911383  0.627974    NaN
# 3      0.690152    0.543856  0.791858  0.412409  0.569077    NaN
# 4      0.695516    0.793135  0.423228  0.548832  0.763728    NaN
# ..          ...         ...       ...       ...       ...    ...
# 329    0.988176    0.369332  0.283541  0.260270  0.627546    NaN
# 330    0.007881    0.385615  0.354426  0.618249  0.341204    NaN
# 331    0.119927    0.124247  0.895262  0.056623  0.178330    NaN
# 332    0.595859    0.187111  0.502048  0.132103  0.883491    NaN
# 333    0.088621    0.832595  0.471849  0.398521  0.738020    NaN
#
# [334 rows x 6 columns]

# %%
newdf=newdf.drop(1,axis=1)

# %%
newdf
# Out:
#               A           B         C         D         E
# 0    654.000000  999.000000  0.800005  0.650373  0.266525
# 1      0.581182    0.113125  0.166101  0.647029  0.520808
# 2      0.560521    0.628288  0.577837  0.911383  0.627974
# 3      0.690152    0.543856  0.791858  0.412409  0.569077
# 4      0.695516    0.793135  0.423228  0.548832  0.763728
# ..          ...         ...       ...       ...       ...
# 329    0.988176    0.369332  0.283541  0.260270  0.627546
# 330    0.007881    0.385615  0.354426  0.618249  0.341204
# 331    0.119927    0.124247  0.895262  0.056623  0.178330
# 332    0.595859    0.187111  0.502048  0.132103  0.883491
# 333    0.088621    0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf.loc[0:3,:]
# Out:
#             A           B         C         D         E
# 0  654.000000  999.000000  0.800005  0.650373  0.266525
# 1    0.581182    0.113125  0.166101  0.647029  0.520808
# 2    0.560521    0.628288  0.577837  0.911383  0.627974
# 3    0.690152    0.543856  0.791858  0.412409  0.569077

# %%
newdf.loc[(newdf['A']<0.3)]
# Out:
#             A         B         C         D         E
# 7    0.037804  0.425762  0.836141  0.030348  0.142122
# 8    0.101813  0.733811  0.614562  0.588037  0.592657
# 12   0.010082  0.832669  0.819355  0.414732  0.544461
# 15   0.175090  0.473107  0.186121  0.094129  0.172350
# 19   0.131507  0.096416  0.306667  0.149102  0.038717
# ..        ...       ...       ...       ...       ...
# 326  0.151256  0.353573  0.777317  0.912079  0.486231
# 328  0.053606  0.987221  0.858564  0.339518  0.421371
# 330  0.007881  0.385615  0.354426  0.618249  0.341204
# 331  0.119927  0.124247  0.895262  0.056623  0.178330
# 333  0.088621  0.832595  0.471849  0.398521  0.738020
#
# [110 rows x 5 columns]

# %%
newdf
# Out:
#               A           B         C         D         E
# 0    654.000000  999.000000  0.800005  0.650373  0.266525
# 1      0.581182    0.113125  0.166101  0.647029  0.520808
# 2      0.560521    0.628288  0.577837  0.911383  0.627974
# 3      0.690152    0.543856  0.791858  0.412409  0.569077
# 4      0.695516    0.793135  0.423228  0.548832  0.763728
# ..          ...         ...       ...       ...       ...
# 329    0.988176    0.369332  0.283541  0.260270  0.627546
# 330    0.007881    0.385615  0.354426  0.618249  0.341204
# 331    0.119927    0.124247  0.895262  0.056623  0.178330
# 332    0.595859    0.187111  0.502048  0.132103  0.883491
# 333    0.088621    0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf.loc[(newdf['A']<0.3)]
# Out:
#             A         B         C         D         E
# 7    0.037804  0.425762  0.836141  0.030348  0.142122
# 8    0.101813  0.733811  0.614562  0.588037  0.592657
# 12   0.010082  0.832669  0.819355  0.414732  0.544461
# 15   0.175090  0.473107  0.186121  0.094129  0.172350
# 19   0.131507  0.096416  0.306667  0.149102  0.038717
# ..        ...       ...       ...       ...       ...
# 326  0.151256  0.353573  0.777317  0.912079  0.486231
# 328  0.053606  0.987221  0.858564  0.339518  0.421371
# 330  0.007881  0.385615  0.354426  0.618249  0.341204
# 331  0.119927  0.124247  0.895262  0.056623  0.178330
# 333  0.088621  0.832595  0.471849  0.398521  0.738020
#
# [110 rows x 5 columns]

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D         E
# 7    0.037804  0.425762  0.836141  0.030348  0.142122
# 8    0.101813  0.733811  0.614562  0.588037  0.592657
# 12   0.010082  0.832669  0.819355  0.414732  0.544461
# 15   0.175090  0.473107  0.186121  0.094129  0.172350
# 19   0.131507  0.096416  0.306667  0.149102  0.038717
# ..        ...       ...       ...       ...       ...
# 326  0.151256  0.353573  0.777317  0.912079  0.486231
# 328  0.053606  0.987221  0.858564  0.339518  0.421371
# 330  0.007881  0.385615  0.354426  0.618249  0.341204
# 331  0.119927  0.124247  0.895262  0.056623  0.178330
# 333  0.088621  0.832595  0.471849  0.398521  0.738020
#
# [97 rows x 5 columns]

# %%
newdf.head(5)
# Out:
#             A           B         C         D         E
# 0  654.000000  999.000000  0.800005  0.650373  0.266525
# 1    0.581182    0.113125  0.166101  0.647029  0.520808
# 2    0.560521    0.628288  0.577837  0.911383  0.627974
# 3    0.690152    0.543856  0.791858  0.412409  0.569077
# 4    0.695516    0.793135  0.423228  0.548832  0.763728

# %%
newdf
# Out:
#               A           B         C         D         E
# 0    654.000000  999.000000  0.800005  0.650373  0.266525
# 1      0.581182    0.113125  0.166101  0.647029  0.520808
# 2      0.560521    0.628288  0.577837  0.911383  0.627974
# 3      0.690152    0.543856  0.791858  0.412409  0.569077
# 4      0.695516    0.793135  0.423228  0.548832  0.763728
# ..          ...         ...       ...       ...       ...
# 329    0.988176    0.369332  0.283541  0.260270  0.627546
# 330    0.007881    0.385615  0.354426  0.618249  0.341204
# 331    0.119927    0.124247  0.895262  0.056623  0.178330
# 332    0.595859    0.187111  0.502048  0.132103  0.883491
# 333    0.088621    0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf.iloc[3,1]
# Out:
# 0.543855835755332

# %%
newdf.iloc[4,3]
# Out:
# 0.5488318107075945

# %%
newdf.iloc[:4,:2]
# Out:
#             A           B
# 0  654.000000  999.000000
# 1    0.581182    0.113125
# 2    0.560521    0.628288
# 3    0.690152    0.543856

# %%
newdf.loc[:4,['A','B','C']]
# Out:
#             A           B         C
# 0  654.000000  999.000000  0.800005
# 1    0.581182    0.113125  0.166101
# 2    0.560521    0.628288  0.577837
# 3    0.690152    0.543856  0.791858
# 4    0.695516    0.793135  0.423228

# %%
newdf
# Out:
#               A           B         C         D         E
# 0    654.000000  999.000000  0.800005  0.650373  0.266525
# 1      0.581182    0.113125  0.166101  0.647029  0.520808
# 2      0.560521    0.628288  0.577837  0.911383  0.627974
# 3      0.690152    0.543856  0.791858  0.412409  0.569077
# 4      0.695516    0.793135  0.423228  0.548832  0.763728
# ..          ...         ...       ...       ...       ...
# 329    0.988176    0.369332  0.283541  0.260270  0.627546
# 330    0.007881    0.385615  0.354426  0.618249  0.341204
# 331    0.119927    0.124247  0.895262  0.056623  0.178330
# 332    0.595859    0.187111  0.502048  0.132103  0.883491
# 333    0.088621    0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf.drop(['A','C'],axis=1)
# Out:
#               B         D         E
# 0    999.000000  0.650373  0.266525
# 1      0.113125  0.647029  0.520808
# 2      0.628288  0.911383  0.627974
# 3      0.543856  0.412409  0.569077
# 4      0.793135  0.548832  0.763728
# ..          ...       ...       ...
# 329    0.369332  0.260270  0.627546
# 330    0.385615  0.618249  0.341204
# 331    0.124247  0.056623  0.178330
# 332    0.187111  0.132103  0.883491
# 333    0.832595  0.398521  0.738020
#
# [334 rows x 3 columns]

# %%
newdf
# Out:
#               A           B         C         D         E
# 0    654.000000  999.000000  0.800005  0.650373  0.266525
# 1      0.581182    0.113125  0.166101  0.647029  0.520808
# 2      0.560521    0.628288  0.577837  0.911383  0.627974
# 3      0.690152    0.543856  0.791858  0.412409  0.569077
# 4      0.695516    0.793135  0.423228  0.548832  0.763728
# ..          ...         ...       ...       ...       ...
# 329    0.988176    0.369332  0.283541  0.260270  0.627546
# 330    0.007881    0.385615  0.354426  0.618249  0.341204
# 331    0.119927    0.124247  0.895262  0.056623  0.178330
# 332    0.595859    0.187111  0.502048  0.132103  0.883491
# 333    0.088621    0.832595  0.471849  0.398521  0.738020
#
# [334 rows x 5 columns]

# %%
newdf.drop(['A','C'],axis=1,inplace=True)

# %%
newdf
# Out:
#               B         D         E
# 0    999.000000  0.650373  0.266525
# 1      0.113125  0.647029  0.520808
# 2      0.628288  0.911383  0.627974
# 3      0.543856  0.412409  0.569077
# 4      0.793135  0.548832  0.763728
# ..          ...       ...       ...
# 329    0.369332  0.260270  0.627546
# 330    0.385615  0.618249  0.341204
# 331    0.124247  0.056623  0.178330
# 332    0.187111  0.132103  0.883491
# 333    0.832595  0.398521  0.738020
#
# [334 rows x 3 columns]

# %%
newdf.drop([1,3,5,6,7,8])
# Out:
#               B         D         E
# 0    999.000000  0.650373  0.266525
# 2      0.628288  0.911383  0.627974
# 4      0.793135  0.548832  0.763728
# 9      0.249673  0.759718  0.440510
# 10     0.519135  0.777449  0.204114
# ..          ...       ...       ...
# 329    0.369332  0.260270  0.627546
# 330    0.385615  0.618249  0.341204
# 331    0.124247  0.056623  0.178330
# 332    0.187111  0.132103  0.883491
# 333    0.832595  0.398521  0.738020
#
# [328 rows x 3 columns]

# %%
newdf
# Out:
#               B         D         E
# 0    999.000000  0.650373  0.266525
# 1      0.113125  0.647029  0.520808
# 2      0.628288  0.911383  0.627974
# 3      0.543856  0.412409  0.569077
# 4      0.793135  0.548832  0.763728
# ..          ...       ...       ...
# 329    0.369332  0.260270  0.627546
# 330    0.385615  0.618249  0.341204
# 331    0.124247  0.056623  0.178330
# 332    0.187111  0.132103  0.883491
# 333    0.832595  0.398521  0.738020
#
# [334 rows x 3 columns]

# %%
newdf.drop([1,3,5,6,7,8],inplace=True)

# %%
newdf.head(10)
# Out:
#              B         D         E
# 0   999.000000  0.650373  0.266525
# 2     0.628288  0.911383  0.627974
# 4     0.793135  0.548832  0.763728
# 9     0.249673  0.759718  0.440510
# 10    0.519135  0.777449  0.204114
# 11    0.448261  0.157207  0.261434
# 12    0.832669  0.414732  0.544461
# 13    0.820323  0.743489  0.246350
# 14    0.878943  0.137201  0.490371
# 15    0.473107  0.094129  0.172350

# %%
newdf
# Out:
#               B         D         E
# 0    999.000000  0.650373  0.266525
# 2      0.628288  0.911383  0.627974
# 4      0.793135  0.548832  0.763728
# 9      0.249673  0.759718  0.440510
# 10     0.519135  0.777449  0.204114
# ..          ...       ...       ...
# 329    0.369332  0.260270  0.627546
# 330    0.385615  0.618249  0.341204
# 331    0.124247  0.056623  0.178330
# 332    0.187111  0.132103  0.883491
# 333    0.832595  0.398521  0.738020
#
# [328 rows x 3 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#               B         D         E
# 0    999.000000  0.650373  0.266525
# 1      0.628288  0.911383  0.627974
# 2      0.793135  0.548832  0.763728
# 3      0.249673  0.759718  0.440510
# 4      0.519135  0.777449  0.204114
# ..          ...       ...       ...
# 323    0.369332  0.260270  0.627546
# 324    0.385615  0.618249  0.341204
# 325    0.124247  0.056623  0.178330
# 326    0.187111  0.132103  0.883491
# 327    0.832595  0.398521  0.738020
#
# [328 rows x 3 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 323    False
# 324    False
# 325    False
# 326    False
# 327    False
# Name: B, Length: 328, dtype: bool

# %%
newdf['B']=None

# %%
newdf
# Out:
#         B         D         E
# 0    None  0.650373  0.266525
# 1    None  0.911383  0.627974
# 2    None  0.548832  0.763728
# 3    None  0.759718  0.440510
# 4    None  0.777449  0.204114
# ..    ...       ...       ...
# 323  None  0.260270  0.627546
# 324  None  0.618249  0.341204
# 325  None  0.056623  0.178330
# 326  None  0.132103  0.883491
# 327  None  0.398521  0.738020
#
# [328 rows x 3 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 323    True
# 324    True
# 325    True
# 326    True
# 327    True
# Name: B, Length: 328, dtype: bool

# %%
newdf.loc[:,['B']]=34

# %%
newdf
# Out:
#       B         D         E
# 0    34  0.650373  0.266525
# 1    34  0.911383  0.627974
# 2    34  0.548832  0.763728
# 3    34  0.759718  0.440510
# 4    34  0.777449  0.204114
# ..   ..       ...       ...
# 323  34  0.260270  0.627546
# 324  34  0.618249  0.341204
# 325  34  0.056623  0.178330
# 326  34  0.132103  0.883491
# 327  34  0.398521  0.738020
#
# [328 rows x 3 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 323    False
# 324    False
# 325    False
# 326    False
# 327    False
# Name: B, Length: 328, dtype: bool

# %%
df=pd.DataFrame({
    "name":['alfred','catwomen','batman'],
    "toy":[np.nan,'Bullwhip','Batmobile'],
    "born":[np.nan,pd.Timestamp("1940-04-25"),np.nan]
})

# %%
df
# Out:
#        name        toy       born
# 0    alfred        NaN        NaT
# 1  catwomen   Bullwhip 1940-04-25
# 2    batman  Batmobile        NaT

# %%
df.dropna()
# Out:
#        name       toy       born
# 1  catwomen  Bullwhip 1940-04-25

# %%
df
# Out:
#        name        toy       born
# 0    alfred        NaN        NaT
# 1  catwomen   Bullwhip 1940-04-25
# 2    batman  Batmobile        NaT

# %%
df.dropna(how='all')
# Out:
#        name        toy       born
# 0    alfred        NaN        NaT
# 1  catwomen   Bullwhip 1940-04-25
# 2    batman  Batmobile        NaT

# %%
df.dropna(how='any')
# Out:
#        name       toy       born
# 1  catwomen  Bullwhip 1940-04-25

# %%
df.iloc[0,0]=np.nan

# %%
df
# Out:
#        name        toy       born
# 0       NaN        NaN        NaT
# 1  catwomen   Bullwhip 1940-04-25
# 2    batman  Batmobile        NaT

# %%
df.dropna(how='all')
# Out:
#        name        toy       born
# 1  catwomen   Bullwhip 1940-04-25
# 2    batman  Batmobile        NaT

# %%
df=pd.DataFrame({
    "name":['alfred','catwomen','batman'],
    "toy":[np.nan,'Bullwhip','Batmobile'],
    "born":[np.nan,pd.Timestamp("1940-04-25"),np.nan]
})

# %%
df
# Out:
#        name        toy       born
# 0    alfred        NaN        NaT
# 1  catwomen   Bullwhip 1940-04-25
# 2    batman  Batmobile        NaT

# %%
df['toy'].value_counts()
# Out:
# Batmobile    1
# Bullwhip     1
# Name: toy, dtype: int64

# %%
df=pd.DataFrame({'A':[1,2,np.nan],
                'B':[5,np.nan,np.nan],
                 'C':[1,2,3]
                })

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df=df.dropna()

# %%
df=pd.DataFrame({'A':[1,2,np.nan],
                'B':[5,np.nan,np.nan],
                 'C':[1,2,3]
                })

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value="fill null value")
# Out:
#                  A                B  C
# 0                1                5  1
# 1                2  fill null value  2
# 2  fill null value  fill null value  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value=df.mean())
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  1.5  5.0  3

# %%
df['A'].fillna(value=df['A'].mean(),inplace=True)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %%
df['B'].fillna(value=df['B'].max(),inplace=True)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  1.5  5.0  3

# %% [markdown]
# **group by

# %%
data={'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
     'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
      'Sales':[200,120,340,124,243,350]
     }

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
#groupby method groups rows together based off a column name.

# %%
by_comp=df.groupby('Company')

# %%
by_comp.mean()
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df.groupby('Company').mean()
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
by_comp.std()
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
by_comp.describe().transpose()['FB']
# Out:
# Sales  count      2.000000
#        mean     296.500000
#        std       75.660426
#        min      243.000000
#        25%      269.750000
#        50%      296.500000
#        75%      323.250000
#        max      350.000000
# Name: FB, dtype: float64

# %% [markdown]
# **merging joining concatenating**

# %%
df1=pd.DataFrame({
    'A':['A0','A1','A2','A3'],
    'B':['B0','B1','B2','B3'],
    'C':['C0','C1','C2','C3'],
    'D':['D0','D1','D2','D3']
})

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2=pd.DataFrame({
    'A':['A4','A5','A6','A7'],
    'B':['B4','B5','B6','B7'],
    'C':['C4','C5','C6','C7'],
    'D':['D4','D5','D6','D7']
},index=[4,5,6,7])

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3=pd.DataFrame({
    'A':['A8','A9','A10','A11'],
    'B':['B8','B9','B10','B11'],
    'C':['C8','C9','C10','C11'],
    'D':['D8','D9','D10','D11']
},index=[8,9,10,11])

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left=pd.DataFrame({
    'key':['K0',"K1",'K2','K3'],
    'A':['A0','A1','A2','A3'],
    'B':['B0','B1','B2','B3']
    
})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right=pd.DataFrame({
     'key':['K0',"K1",'K2','K3'],
    'C':['C0','C1','C2','C3'],
    'D':['D0','D1','D2','D3']
})

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left=pd.DataFrame({
    'key1':['K0',"K1",'K2','K3'],
    'key2':['K0','K1','K0','K1'],
    'A':['A0','A1','A2','A3'],
    'B':['B0','B1','B2','B3']
    
})

right=pd.DataFrame({
     'key1':['K0',"K1",'K2','K3'],
    'key2':['K0','K0','K0','K0'],
    'C':['C0','C1','C2','C3'],
    'D':['D0','D1','D2','D3']
})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K1   K1  A1  B1
# 2   K2   K0  A2  B2
# 3   K3   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K2   K0  C2  D2
# 3   K3   K0  C3  D3

# %%
pd.merge(left,right,on=['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K2   K0  A2  B2  C2  D2

# %%
pd.merge(left,right,how='outer',on=['key1','key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K1   K1   A1   B1  NaN  NaN
# 2   K2   K0   A2   B2   C2   D2
# 3   K3   K1   A3   B3  NaN  NaN
# 4   K1   K0  NaN  NaN   C1   D1
# 5   K3   K0  NaN  NaN   C3   D3

# %% [markdown]
# **join**

# %%
left=pd.DataFrame({
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
    
},index=['K0',"K1",'K2'])

right=pd.DataFrame({
     
    'C':['C0','C2','C3'],
    'D':['D0','D2','D3']
},index=['K0','K2','K3'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left.join(right,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
df=pd.DataFrame({'A':[1,2,np.nan],
                'B':[5,np.nan,np.nan],
                 'C':[1,2,3]
                })

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df=df.dropna()

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df=pd.DataFrame({'A':[1,2,np.nan],
                'B':[5,np.nan,np.nan],
                 'C':[1,2,3]
                })

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
dt1=pd.read_csv('https://bit.ly/imdbratings')

# %%
dt1.shape
# Out:
# (979, 6)

# %%
type(dt1)
# Out:
# pandas.core.frame.DataFrame

# %%
dt1.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
dt1.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %%
dt1=pd.read_csv('https://bit.ly/imdbratings',nrows=100,usecols=[1,3,4])

# %%
dt1
# Out:
#                        title      genre  duration
# 0   The Shawshank Redemption      Crime       142
# 1              The Godfather      Crime       175
# 2     The Godfather: Part II      Crime       200
# 3            The Dark Knight     Action       152
# 4               Pulp Fiction      Crime       154
# ..                       ...        ...       ...
# 95             All About Eve      Drama       138
# 96                   Yojimbo     Action       110
# 97                 The Sting     Comedy       129
# 98                  Rashomon      Crime        88
# 99                   Amadeus  Biography       160
#
# [100 rows x 3 columns]

# %%
dt1=pd.read_csv('https://bit.ly/imdbratings')

# %%
dt1
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
dt1['duration']
# Out:
# 0      142
# 1      175
# 2      200
# 3      152
# 4      154
#       ...
# 974    116
# 975    118
# 976    138
# 977    114
# 978    126
# Name: duration, Length: 979, dtype: int64

# %%
x.shape
# Out:
# (11, 6)

# %%
x
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
df=pd.read_csv('https://bit.ly/imdbratings')

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[df.duration>200]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
df[(df.duration>200) & (df.genre=='Adventure')]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %%
df[df.duration>200]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
df[(df.duration>200)&((df.genre=="Adventure")|(df.genre=='Crime'))]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 78               R      Crime       229
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# ...

# %%
df[(df.duration>200)&(df.genre.isin(['Crime','Adventure','Action']))]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 78               R      Crime       229
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
# 767       APPROVED     Action       205
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# ...

# %%
df.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df.genre.nunique()
# Out:
# 16

# %%
df[(df.duration>200)][(df.genre=='Drama')]
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
df[(df.duration>200)&(df.genre=='Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
df.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.star_rating.max()
# Out:
# 9.3

# %%
df.star_rating.min(),df.star_rating.mean()
# Out:
# (7.4, 7.8897854954034985)

# %%
df.star_rating.agg(['min','max','mean','count','sum'])
# Out:
# min         7.400000
# max         9.300000
# mean        7.889785
# count     979.000000
# sum      7724.100000
# Name: star_rating, dtype: float64

# %%
df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df[df.genre=='Drama'][['star_rating','duration']].agg(['min','max','mean','count','sum'])
# Out:
#        star_rating      duration
# min       7.400000     64.000000
# max       8.900000    242.000000
# mean      7.902518    126.539568
# count   278.000000    278.000000
# sum    2196.900000  35178.000000

# %%
df[df.genre=='Drama'].describe()
# Out:
#        star_rating    duration
# count   278.000000  278.000000
# mean      7.902518  126.539568
# std       0.328041   25.637086
# min       7.400000   64.000000
# 25%       7.600000  108.000000
# 50%       7.900000  123.000000
# 75%       8.100000  138.000000
# max       8.900000  242.000000

# %%
df.groupby('genre').star_rating.describe()
# Out:
#            count      mean       std  min    25%   50%    75%  max
# genre
# Action     136.0  7.884559  0.333084  7.4  7.600  7.80  8.100  9.0
# Adventure   75.0  7.933333  0.361802  7.4  7.650  7.90  8.100  8.9
# Animation   62.0  7.914516  0.292444  7.4  7.700  7.90  8.100  8.6
# Biography   77.0  7.862338  0.310364  7.4  7.600  7.80  8.100  8.9
# Comedy     156.0  7.822436  0.304922  7.4  7.600  7.80  8.000  8.6
# Crime      124.0  7.916935  0.392143  7.4  7.600  7.80  8.100  9.3
# Drama      278.0  7.902518  0.328041  7.4  7.600  7.90  8.100  8.9
# Family       2.0  7.850000  0.070711  7.8  7.825  7.85  7.875  7.9
# Fantasy      1.0  7.700000       NaN  7.7  7.700  7.70  7.700  7.7
# Film-Noir    3.0  8.033333  0.305505  7.7  7.900  8.10  8.200  8.3
# History      1.0  8.000000       NaN  8.0  8.000  8.00  8.000  8.0
# Horror      29.0  7.806897  0.337989  7.4  7.500  7.70  8.000  8.6
# Mystery     16.0  7.975000  0.387298  7.4  7.575  8.10  8.225  8.6
# ...

# %%
df.groupby('genre').duration.describe()
# Out:
#            count        mean        std    min     25%    50%     75%    max
# genre
# Action     136.0  126.485294  21.982480   80.0  111.00  125.0  137.00  205.0
# Adventure   75.0  134.840000  33.383942   89.0  109.00  127.0  151.50  224.0
# Animation   62.0   96.596774  13.975927   75.0   87.00   94.5  102.00  134.0
# Biography   77.0  131.844156  24.283991   85.0  116.00  127.0  146.00  202.0
# Comedy     156.0  107.602564  20.101574   68.0   94.00  104.0  117.00  187.0
# Crime      124.0  122.298387  25.054406   67.0  104.75  118.0  134.25  229.0
# Drama      278.0  126.539568  25.637086   64.0  108.00  123.0  138.00  242.0
# Family       2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy      1.0  112.000000        NaN  112.0  112.00  112.0  112.00  112.0
# Film-Noir    3.0   97.333333  12.096832   88.0   90.50   93.0  102.00  111.0
# History      1.0   66.000000        NaN   66.0   66.00   66.0   66.00   66.0
# ...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[df.actors_list.str.contains('Khan')]
# Out:
#      star_rating                              title content_rating      genre  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 89           8.4                             Swades      NOT RATED      Drama
# 93           8.4        Dilwale Dulhania Le Jayenge      NOT RATED     Comedy
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 336          8.0                         Life of Pi             PG  Adventure
# 373          8.0                    My Name Is Khan          PG-13      Drama
# 718          7.6                    The Kite Runner          PG-13      Drama
#
#      duration                                        actors_list
# ...

# %%
a='print("hello")'

# %%
a
# Out:
# 'print("hello")'

# %%
eval(a)
# Out:
# hello

# %%
ac=[]
for i in df.actors_list:
    ac.extend(eval(i))

# %%
ac
# Out:
# ['Tim Robbins',
#  'Morgan Freeman',
#  'Bob Gunton',
#  'Marlon Brando',
#  'Al Pacino',
#  'James Caan',
#  'Al Pacino',
#  'Robert De Niro',
#  'Robert Duvall',
#  'Christian Bale',
#  'Heath Ledger',
#  'Aaron Eckhart',
#  'John Travolta',
#  'Uma Thurman',
#  'Samuel L. Jackson',
#  'Henry Fonda',
#  'Lee J. Cobb',
#  'Martin Balsam',
#  'Clint Eastwood',
#  'Eli Wallach',
#  'Lee Van Cleef',
#  'Elijah Wood',
#  'Viggo Mortensen',
#  'Ian McKellen',
#  'Liam Neeson',
#  'Ralph Fiennes',
#  'Ben Kingsley',
#  'Brad Pitt',
#  'Edward Norton',
#  'Helena Bonham Carter',
#  'Elijah Wood',
#  'Ian McKellen',
#  'Orlando Bloom',
#  'Leonardo DiCaprio',
#  'Joseph Gordon-Levitt',
#  'Ellen Page',
#  'Mark Hamill',
#  'Harrison Ford',
#  'Carrie Fisher',
#  'Tom Hanks',
#  'Robin Wright',
#  'Gary Sinise',
#  'Elijah Wood',
#  'Ian McKellen',
#  'Viggo Mortensen',
#  'Matthew McConaughey',
#  'Anne Hathaway',
#  'Jessica Chastain',
#  'Jack Nicholson',
#  'Louise Fletcher',
# ...

# %%
l=[]

# %%
l.append('hello')

# %%
l
# Out:
# ['hello']

# %%
l.extend('python')

# %%
l
# Out:
# ['hello', 'p', 'y', 't', 'h', 'o', 'n']

# %%
len(ac)
# Out:
# 2937

# %%
l=[11,12,13,11,12,13,11,12,13]

# %%
l
# Out:
# [11, 12, 13, 11, 12, 13, 11, 12, 13]

# %%
set(l)
# Out:
# {11, 12, 13}

# %%
len(set(ac))
# Out:
# 1777

# %%
dt=pd.read_csv('https://bit.ly/chiporders',sep='\t')

# %%
dt
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
dt[dt.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...     $8.49
# ...                                                 ...        ...
# ...

# %%
dt
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
dt[dt.item_name.str.lower().str.contains('chicken')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# ...

# %%
a='ShaSHish'

# %%
b='shashish'

# %%
a==b
# Out:
# False

# %%
a.lower()==b
# Out:
# True

# %%
a.lower()
# Out:
# 'shashish'

# %%
dt
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
dt[dt.item_price<5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-294-f38618bd5d31> in <module>
# ----> 1 dt[dt.item_price<5]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     524         rvalues = extract_array(other, extract_numpy=True)
#     525
# --> 526         res_values = comparison_op(lvalues, rvalues, op)
#     527
#     528         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# ...

# %%
dt
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
dt.item_price=dt.item_price.str.lstrip('$')

dt.item_price=dt.item_price.astype(dtype='f')

# %%
dt.item_price
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float32

# %%
dt.loc['item_price']=dt.item_price

# %%
dt
# Out:
#             order_id  quantity                              item_name  \
# 0                1.0       1.0           Chips and Fresh Tomato Salsa
# 1                1.0       1.0                                   Izze
# 2                1.0       1.0                       Nantucket Nectar
# 3                1.0       1.0  Chips and Tomatillo-Green Chili Salsa
# 4                2.0       2.0                           Chicken Bowl
# ...              ...       ...                                    ...
# 4618          1833.0       1.0                          Steak Burrito
# 4619          1834.0       1.0                     Chicken Salad Bowl
# 4620          1834.0       1.0                     Chicken Salad Bowl
# 4621          1834.0       1.0                     Chicken Salad Bowl
# item_price       NaN       NaN                                    NaN
#
#                                            choice_description  item_price
# ...

# %%
dt[dt.item_price<5]
# Out:
#       order_id  quantity                              item_name  \
# 0          1.0       1.0           Chips and Fresh Tomato Salsa
# 1          1.0       1.0                                   Izze
# 2          1.0       1.0                       Nantucket Nectar
# 3          1.0       1.0  Chips and Tomatillo-Green Chili Salsa
# 6          3.0       1.0                          Side of Chips
# ...        ...       ...                                    ...
# 4606    1828.0       1.0                      Canned Soft Drink
# 4609    1829.0       1.0                      Canned Soft Drink
# 4613    1831.0       1.0                                  Chips
# 4614    1831.0       1.0                          Bottled Water
# 4616    1832.0       1.0                    Chips and Guacamole
#
#      choice_description  item_price
# 0                   NaN        2.39
# 1          [Clementine]        3.39
# 2               [Apple]        3.39
# 3                   NaN        2.39
# ...

# %%
dt2=pd.read_csv('https://bit.ly/drinksbycountry')

# %%
dt2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
dt2.shape
# Out:
# (193, 6)

# %%
dt2.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
dt2[0:10:2]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 2      Algeria             25                0             14
# 4       Angola            217               57             45
# 6    Argentina            193               25            221
# 8    Australia            261               72            212
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 2                           0.7         Africa
# 4                           5.9         Africa
# 6                           8.3  South America
# 8                          10.4        Oceania

# %%
dt2[dt2.beer_servings<200]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0          Afghanistan              0                0              0
# 1              Albania             89              132             54
# 2              Algeria             25                0             14
# 5    Antigua & Barbuda            102              128             45
# 6            Argentina            193               25            221
# ..                 ...            ...              ...            ...
# 187            Vanuatu             21               18             11
# 189            Vietnam            111                2              1
# 190              Yemen              6                0              0
# 191             Zambia             32               19              4
# 192           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# ...

# %%
dt2.loc[2]
# Out:
# country                         Algeria
# beer_servings                        25
# spirit_servings                       0
# wine_servings                        14
# total_litres_of_pure_alcohol        0.7
# continent                        Africa
# Name: 2, dtype: object

# %%
dt2.loc['Australia']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# KeyError: 'Australia'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-316-776a527c5014> in <module>
# ----> 1 dt2.loc['Australia']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
# ...

# %%
dt2.head(20)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# ...

# %%
dt2[50:100]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 50            Dominica             52              286             26
# 51  Dominican Republic            193              147              9
# 52             Ecuador            162               74              3
# 53               Egypt              6                4              1
# 54         El Salvador             52               69              2
# 55   Equatorial Guinea             92                0            233
# 56             Eritrea             18                0              0
# 57             Estonia            224              194             59
# 58            Ethiopia             20                3              0
# 59                Fiji             77               35              1
# 60             Finland            263              133             97
# 61              France            127              151            370
# ...

# %%
dt2.iloc[77]
# Out:
# country                         India
# beer_servings                       9
# spirit_servings                   114
# wine_servings                       0
# total_litres_of_pure_alcohol      2.2
# continent                        Asia
# Name: 77, dtype: object

# %%
dt2.loc['india']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# KeyError: 'india'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-322-4cae78aa6e4a> in <module>
# ----> 1 dt2.loc['india']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
# ...

# %%
dt2[dt2.country=='India']
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 77   India              9              114              0
#
#     total_litres_of_pure_alcohol continent
# 77                           2.2      Asia

# %%
df=pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df=pd.read_csv('https://bit.ly/imdbratings')

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.duration==200)&((df.genre=="Adventure")|(df.genre=='Crime'))]
# Out:
#    star_rating                   title content_rating  genre  duration  \
# 2          9.1  The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df=pd.read_excel('Excel_Sample.xlsx')

# %%
df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15
# 4           4  16  17  18  19

# %%
#lxml,html5lib,BeautifulSoup4
